# %% [markdown]
# # Checks — reproducible evidence for this ticket
# Any language. One markdown why-note + one code cell per verified check (via `append_notebook_cell.py`).

# %%
# cell 0 - setup: connections/imports for whatever your checks need (keep environments explicit)
