# %% [markdown]
# # Master — combined per-environment checks
# Every recorded check = one markdown why-note + one code cell (via `append_notebook_cell.py`).

# %%
# cell 0 - config: connections for your platforms/environments (UAT vs PROD kept explicit and separate)
